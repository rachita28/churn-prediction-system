# %%
import pandas as pd

# Load the raw dataset we just generated
df = pd.read_csv("../data/raw/telecom_churn.csv")

# Print the shape (rows, columns) and show the first 5 rows
print(f"Dataset Shape: {df.shape}")
df.head()
# Out:
# Dataset Shape: (5000, 15)
#   CustomerID  Gender  SeniorCitizen Partner Dependents  TenureMonths  \
# 0  TEL-00001    Male              0      No        Yes            28
# 1  TEL-00002  Female              0      No        Yes            22
# 2  TEL-00003    Male              0      No        Yes            16
# 3  TEL-00004    Male              1     Yes        Yes            13
# 4  TEL-00005    Male              0     Yes        Yes            62
#
#   PhoneService     MultipleLines InternetService        Contract  \
# 0          Yes  No phone service     Fiber optic  Month-to-month
# 1          Yes               Yes     Fiber optic  Month-to-month
# 2          Yes               Yes     Fiber optic        One year
# 3          Yes                No     Fiber optic  Month-to-month
# 4          Yes                No     Fiber optic        Two year
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges TotalCharges Churn
# ...

# %%
# Check data types and check for missing/messy entries
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        5000 non-null   str
#  1   Gender            5000 non-null   str
#  2   SeniorCitizen     5000 non-null   int64
#  3   Partner           5000 non-null   str
#  4   Dependents        5000 non-null   str
#  5   TenureMonths      5000 non-null   int64
#  6   PhoneService      5000 non-null   str
#  7   MultipleLines     5000 non-null   str
#  8   InternetService   5000 non-null   str
#  9   Contract          5000 non-null   str
#  10  PaperlessBilling  5000 non-null   str
#  11  PaymentMethod     5000 non-null   str
#  12  MonthlyCharges    5000 non-null   float64
#  13  TotalCharges      5000 non-null   str
#  14  Churn             5000 non-null   str
# dtypes: float64(1), int64(2), str(12)
# memory usage: 586.1 KB
